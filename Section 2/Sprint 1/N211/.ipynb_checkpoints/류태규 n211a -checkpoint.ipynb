# %% [markdown]
# <img align="right" src="https://ds-cs-images.s3.ap-northeast-2.amazonaws.com/Codestates_Fulllogo_Color.png" width=100>
#
# ## *DATA SCIENCE / SECTION 2 / SPRINT 1 / NOTE 1*
#
# # 📝 Assignment
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv('https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/kc_house_data/kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ------
# # 1

# %%
# 카테고리 별 상관계수 확인
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
# 'price' 항목과 다른 항목들 간의 상관계수만 확인, 내림차순 정렬
print(df.corr().sort_values('price', ascending = False)[['price']])

#'sqft_living' 항목이 가장 상관계수가 높음을 확인.
# Out:
#                   price
# price          1.000000
# sqft_living    0.702035
# grade          0.667434
# sqft_above     0.605567
# sqft_living15  0.585379
# bathrooms      0.525138
# view           0.397293
# sqft_basement  0.323816
# bedrooms       0.308350
# lat            0.307003
# waterfront     0.266369
# floors         0.256794
# yr_renovated   0.126434
# sqft_lot       0.089661
# sqft_lot15     0.082447
# yr_built       0.054012
# condition      0.036362
# long           0.021626
# id            -0.016762
# zipcode       -0.053203

# %%
pd.DataFrame(df.corr().sort_values('price', ascending = False)[['price']].iloc[1]).columns.values[0]
# Out:
# 'sqft_living'

# %%
df.corr().sort_values('price', ascending = False)[['price']].index.values[1]
# Out:
# 'sqft_living'

# %%
# 'price'와 'sqft_living'의 관계 시각화.

x_sqft = df['sqft_living']
y_price = df['price']

predict = df['price'].mean()
errors = predict - df['price']
mean_absolute_error_predict = errors.abs().mean()

sns.lineplot(x=x_sqft, y=predict, color='red')
sns.scatterplot(x=x_sqft, y=y_price, color='blue');

# %% [markdown]
# ----
# # 2.

# %%
x_grade = df['grade']
y_price = df['price']

predict = df['price'].mean()
errors = predict - df['price']
mean_absolute_error_predict = errors.abs().mean()

sns.lineplot(x=x_grade, y=predict, color='red')
sns.scatterplot(x=x_grade, y=y_price, color='blue');

# %%
#기준 모델 값
predict
# Out:
# 540088.1417665294

# %% [markdown]
# ---
# # 3.

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

feature_grade = ['grade']
target_price = ['price']
X_train_grade = df[feature_grade]
y_train_price = df[target_price]

model.fit(X_train_grade, y_train_price)


# grade 값에 따른 예측 모델 = 파란 선

X_test_grade = [[x] for x in df['grade']]
y_pred_price = model.predict(X_test_grade)

plt.figure(figsize=(10, 10))

plt.ticklabel_format(style='plain')

plt.scatter(X_train_grade, y_train_price, color = 'orange', alpha = 0.2)
plt.plot(X_test_grade, y_pred_price, color='blue', linewidth = 3)

# %%
# grade 6인 경우 예측 가격

X_test_grade6 = [[6]] # grade 값 입력
y_pred_grade6 = model.predict(X_test_grade6)

y_pred_grade6
# Out:
# array([[194700.39774049]])

# %% [markdown]
# ---
# # 4

# %%
# 'grade' 특성에 대한 회귀 계수 coefficient

model.fit(X_train_grade, y_train_price)

print("계수 : {}".format(model.coef_))
print("절편 : {}".format(model.intercept_))
# Out:
# 계수 : [[208457.56245839]]
# 절편 : [-1056044.97700984]

# %%
def prediction(grade):
    y_pred = model.predict([[grade]])
    pred = f"{int(grade)} grade 예측 가격: ${int(y_pred[0])} (1 grade당 추가금: ${int(model.coef_[0])})"
    return pred

print(prediction(5))
# Out:
# 5 grade 예측 가격: $-13757 (1 grade당 추가금: $208457)

# %%
# 예측 모델 그래프
# ^y = ax + b 그래프 그려보기

x = np.arange(0,15)
y = x * model.coef_[0] + model.intercept_

fig, ax = plt.subplots()

plt.xlim([0,10])
plt.title("Price per Grades prediction model")

ax.plot(x, y, color = 'blue')
ax.ticklabel_format(useOffset=False)
ax.ticklabel_format(style='plain')

plt.show()


# 계수 coefficient(208457)은 기울기로 grade 값이 1 증가 할 때마다 208457만큼 가격이 상승한다는 것을 뜻한다. 
# 절편 intercept(-1056044)는 grade가 0일 때, 가격이 -1058044임을 뜻한다. 

from ipywidgets import interact

@interact
def prediction(grade = (1,10)):
    y_pred = model.predict([[grade]])
    pred = f"{int(grade)} grade 예측 가격: ${int(y_pred[0])} (1 grade당 추가금: ${int(model.coef_[0])})"
    return pred
# Out:
# interactive(children=(IntSlider(value=5, description='grade', max=10, min=1), Output()), _dom_classes=('widget…

# %% [markdown]
# ---
# # 5.

# %%
### 이곳에서 과제를 진행해 주세요 ###


from sklearn.linear_model import LinearRegression

model = LinearRegression()

feature_sqft = ['sqft_living']
target_price = ['price']
X_train_sqft = df[feature_sqft]
y_train_price = df[target_price]

model.fit(X_train_sqft, y_train_price)



X_test_sqft = [[x] for x in df['sqft_living']]
y_pred_price = model.predict(X_test_sqft)

plt.figure(figsize=(10, 10))

plt.scatter(X_train_sqft, y_train_price, color = 'pink', alpha = 0.5)
plt.plot(X_test_sqft, y_pred_price, color='orange', linewidth = 3)

# %%
import seaborn as sns

fig, axes = plt.subplots(2, figsize=(10,10))


sns.regplot(x=df['grade'], y=df['price'], ax = axes[0])
sns.regplot(x=df['sqft_living'], y=df['price'], ax = axes[1])


@interact
def prediction(grade = (1,15)):
    y_pred = model.predict([[grade]])
    pred = f"{int(grade)} grade 예측 가격: ${int(y_pred[0])} (1 grade당 추가금: ${int(model.coef_[0])})"
    return pred

@interact
def prediction(sqft = (1,15000)):
    y_pred = model.predict([[sqft]])
    pred = f"{int(sqft)} sqft 예측 가격: ${int(y_pred[0])} (1 sqft당 추가금: ${int(model.coef_[0])})"
    return pred
# Out:
# interactive(children=(IntSlider(value=8, description='grade', max=15, min=1), Output()), _dom_classes=('widget…
# interactive(children=(IntSlider(value=7500, description='sqft', max=15000, min=1), Output()), _dom_classes=('w…

# %%
from sklearn.metrics import mean_absolute_error

mae_grade = mean_absolute_error(df['price'], X_test_grade)
mae_sqft = mean_absolute_error(df['price'], X_test_sqft)

print("grade 항목을 사용한 가격 예측 모델의 MAE : {}".format(mae_grade))
print("sqft_living 항목을 사용한 가격 예측 모델의 MAE : {}".format(mae_sqft))
print(mae_grade > mae_sqft)
# Out:
# grade 항목을 사용한 가격 예측 모델의 MAE : 540080.4848933512
# sqft_living 항목을 사용한 가격 예측 모델의 MAE : 538008.2420302596
# True

# %% [markdown]
# ### *sqft_living 항목을 사용하여 만든 가격 예측 모델의 MAE값이 낮으므로, grade 항목을 사용하는 것보다 정확하다고 할 수 있다.*
# ### *처음에 상관계수가 가장 높았던 항목도 sqft_living 항목이므로, 상관계수가 높은 항목을 사용할 수록 예측 모델의 정확도가 높다고 생각된다.*

# %% [markdown]
# ---

# %% [markdown]
# ## 6.
#
# 좋은 특성이란, 타겟의 변화를 가장 잘 반영하는 특성일 것이다.
# 이를 위하여 타겟인 종속변수와 독립변수간의 관계가 유의미한 관계가 있는 특성을 선택하여야 한다.
#
# 즉 특성간의 상관계수 혹은 모집단에서 유의한 지를 판단하기 위한 검정통계량 등을 통해,
# 실제 값을 얼마나 잘 설명해 줄 수 있는 지 적합도를 계산하여야 한다.

# %% [markdown]
# ## 7.
# OLS (ordinary least squares)란 최소제곱법(least sqare method)의 일종으로 회귀분석의 한 종류이다.
# 최소제곱법과 동일한 의미로 쓰이기도 한다. 정확히는 가장 편하고 일반적인 최소제곱법이라고 볼 수 있다.
# 예측 모델을 뜻하는 추세선을 그릴 때, 각 데이터들로부터의 거리의 합이 가장 짧은 추세선을 그리는 방식이다.
# 이 추세선과 실제 데이터들 간의 거리를 잔차(error)라고 하며, 절대값으로 거리를 구하기 위하여 실제 차이에 제곱을 한다.
#
# 즉, 아래 그림과 같이 각 데이터들과 추세선 간의 거리(잔차)의 합이 가장 적을 때, 가장 정확한 예측 모델을 만들 수 있다고 생각하는 방식이다.
#
# ![image.png](attachment:image.png)
